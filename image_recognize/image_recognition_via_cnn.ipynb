# %% [markdown]
# <img src="https://gallery.mailchimp.com/f98d5ac0a3fbbdcdda35136ab/images/f937a4fd-77b6-416e-9f0f-6f8089ddb084.png" align="center"/>

# %% [markdown]
# <h1><center>Image Recognition Via CNN<h1>

# %% [markdown]
# <font color=darkblue><h3>**Name of Apprentice: Sun Yikang**</h3></font>
# <font color=darkblue><h3>**Kelaberetiv Email: yikang_sun@kelaberetiv.sg**</h3></font>

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('stop.png')
plt.imshow(img)

# %%
img_blue = img[:,:,2]
plt.imshow(img_blue)

# %%
img[100, 100]
# Out:
# array([0.00784314, 0.39215687, 0.73333335], dtype=float32)

# %%
img_square = img
img_square[200:400, 200:400, :] = [0, 1, 0]
plt.imshow(img_square)
plt.show()
